# %%
# importing libraries and datasets
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.datasets import load_iris
iris = load_iris()

# %%
# creating the dataframes
main_df = pd.DataFrame(iris.data, columns = iris.feature_names)
main_df['target'] = iris.target
df_0 = main_df[:50]
df_1 = main_df[50:100]
df_2 = main_df[100:]

# %%
# Creating plot of Class-0 vs Class-1
plt.xlabel('Sepal Length ->')
plt.ylabel('Sepal Width ->')
plt.scatter(df_0['sepal length (cm)'], df_0['sepal width (cm)'], color = 'green', marker = 'x')
plt.scatter(df_1['sepal length (cm)'], df_1['sepal width (cm)'], color = 'blue', marker = '+')

# %%
# Creating plot of Class-1 vs Class-2
plt.xlabel('Sepal Length ->')
plt.ylabel('Sepal Width ->')
plt.scatter(df_1['sepal length (cm)'], df_1['sepal width (cm)'], color = 'blue', marker = '+')
plt.scatter(df_2['sepal length (cm)'], df_2['sepal width (cm)'], color = 'red', marker = 'o')

# %%
# Creating plot of Class-2 vs Class-0
plt.xlabel('Sepal Length ->')
plt.ylabel('Sepal Width ->')
plt.scatter(df_2['sepal length (cm)'], df_2['sepal width (cm)'], color = 'red', marker = 'o')
plt.scatter(df_0['sepal length (cm)'], df_0['sepal width (cm)'], color = 'green', marker = 'x')

# %%
# Applying the train_test_split
X = main_df.drop('target', axis='columns')
Y = main_df['target']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
# Training the data using SVM model
model = SVC()
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
# Predicting the test data
pred = model.predict(x_test)
pred_df = x_test
pred_df['target_predicted'] = pred
pred_df['actual_target'] = y_test
pred_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 66                 5.6               3.0                4.5               1.5
# 51                 6.4               3.2                4.5               1.5
# 111                6.4               2.7                5.3               1.9
# 73                 6.1               2.8                4.7               1.2
# 134                6.1               2.6                5.6               1.4
# 149                5.9               3.0                5.1               1.8
# 49                 5.0               3.3                1.4               0.2
# 63                 6.1               2.9                4.7               1.4
# 99                 5.7               2.8                4.1               1.3
# 15                 5.7               4.4                1.5               0.4
# 32                 5.2               4.1                1.5               0.1
# ...

# %%
# Calculating the score of the model
model.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# > SVM is a supervised learning model.
#
# > It tries to solve both classification as well as regression problems.
#
# > Support vectors are the closest points to the opposite class.
#
# > We chose the hyperplane having the maximum margin.
